# %%
from pywaffle import Waffle
import matplotlib.pyplot as plt

# %%
incidence = {'pedestrians':230,'attacks':4}

# %%
fig = plt.figure(FigureClass=Waffle, 
                    figsize=(15,5), 
                    values=incidence, 
                    icons=['car','swimmer'],
                    rows=10)
# Out:
# <Waffle size 1080x360 with 1 Axes>

# %%
character = ["\U0001F697","\U0001F988"]
character
# Out:
# ['🚗', '🦈']
