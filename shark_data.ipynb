# %%
# Dependencies
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import requests
import json
import gmaps
from config import g_key
gmaps.configure(api_key=g_key)

# %%
# import filtered shark csv file
filename = "Resource/Shark Data WA 2016-2021 (filtered).xls"
shark_data = pd.read_excel(filename)
shark_data.head()
# Out:
#   Case Number         Date    Year        Type    Country               Area  \
# 0  2021.07.19  19-Jul-2021  2021.0  Unprovoked  AUSTRALIA  Western Australia
# 1  2021.07.05  05-Jul-2021  2021.0  Unprovoked  AUSTRALIA    New South Wales
# 2  2021.06.23  23-Jun-2021  2021.0  Unprovoked  AUSTRALIA  Western Australia
# 3  2021.06.11  11-Jun-2021  2021.0  Unprovoked  AUSTRALIA  Western Australia
# 4  2021.05.21  21-May-2021  2021.0  Unprovoked  AUSTRALIA  Western Australia
#
#             Location      Activity              Name Sex   ... Fatal (Y/N)  \
# 0    Rottnest Island       Surfing              male    M  ...           N
# 1      Crescent Head       Surfing       Joe Hoffman    M  ...           N
# 2       Gum Tree Bay       Surfing        Alex Dodds    M  ...           N
# 3  Five Fingers Reef    Snorkeling  Jackson Bartlett    M  ...           N
# 4     Quondong Beach  Spearfishing   Brett Highlands    M  ...           N
#
#     Time                  Species   \
# 0  12h30           White shark, 3m
# 1  16h30                       NaN
# 2  14h00                       NaN
# 3  11h00  Bronze whaler shark, 2 m
# 4  11h20                       NaN
#
#                               Investigator or Source  \
# 0                      B. Myatt & S. De Marchi, GSAF
# 1  S. De Marchi, M. Michaelson, B. Myatt, GSAF an...
# 2  B. Myatt, S. De Marchi & S. Curatololo-Wageman...
# 3                                     B. Myatt, GSAF
# 4                                     B. Myatt, GSAF
#
#                         pdf  \
# 0   2021.07.19-Rottnest.pdf
# 1    2021.07.05-Hoffman.pdf
# 2      2021.06.23-Dodds.pdf
# 3   2021.06.11-Bartlett.pdf
# 4  2021.05.21-Highlands.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2021.07.19
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2021.07.05
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2021.06.23
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2021.06.11
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2021.05.21
#
#   Case Number.2 original order
# 0    2021.07.19           6668
# 1    2021.07.05           6661
# 2    2021.06.23           6655
# 3    2021.06.11           6649
# 4    2021.05.21           6646
#
# [5 rows x 22 columns]

# %%
shark_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163 entries, 0 to 162
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             163 non-null    object
#  1   Date                    163 non-null    object
#  2   Year                    162 non-null    float64
#  3   Type                    163 non-null    object
#  4   Country                 163 non-null    object
#  5   Area                    163 non-null    object
#  6   Location                161 non-null    object
#  7   Activity                156 non-null    object
#  8   Name                    160 non-null    object
#  9   Sex                     158 non-null    object
#  10  Age                     118 non-null    object
#  11  Injury                  162 non-null    object
#  12  Fatal (Y/N)             155 non-null    object
#  13  Time                    137 non-null    object
#  14  Species                 106 non-null    object
#  15  Investigator or Source  162 non-null    object
#  16  pdf                     163 non-null    object
#  17  href formula            163 non-null    object
#  18  href                    163 non-null    object
#  19  Case Number.1           163 non-null    object
#  20  Case Number.2           163 non-null    object
#  21  original order          163 non-null    int64
# dtypes: float64(1), int64(1), object(20)
# memory usage: 28.1+ KB

# %%
shark_data['Area'].unique()
# Out:
# array(['Western Australia', 'New South Wales', 'Queensland',
#        'South Australia', 'Victoria', 'Tasmania', 'Northern Territory ',
#        'New South Wales ', 'Westerm Australia'], dtype=object)

# %%
# clean up misspelled State
shark_data['Area'] = shark_data['Area'].replace({'Westerm Australia':'Western Australia'})
shark_data['Area'] = shark_data['Area'].replace({'New South Wales ':'New South Wales'})

# %%
# remove unwanted columns
shark_df = shark_data.drop(['Name','Investigator or Source'], axis = 1)

# %%
shark_df['Location'].nunique()
# Out:
# 148

# %%
# match location to lat and long coordinates, using Google Maps API

# create columns to hold data
shark_df['lat']=""
shark_df['lng']=""

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"

params = {"key": g_key, "inputtype": "textquery", "fields":"geometry"}

for index, row in shark_df.iterrows():
    # get extra parameters
    params['input'] = (f'{row["Location"]}, {row["Area"]}')
    
    # Run request
    print(f"Retrieving Results for Index {index}: {row['Location']}.")
    response = requests.get(base_url, params=params)
    results = response.json()

    # Extract lat/lng
    try:
        shark_df.loc[index, 'lat'] = results['candidates'][0]['geometry']['location']['lat']
        shark_df.loc[index, 'lng'] = results['candidates'][0]['geometry']['location']['lng'] 
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# Retrieving Results for Index 0: Rottnest Island.
# Retrieving Results for Index 1: Crescent Head.
# Retrieving Results for Index 2: Gum Tree Bay.
# Retrieving Results for Index 3: Five Fingers Reef.
# Retrieving Results for Index 4: Quondong Beach.
# Retrieving Results for Index 5: Turncurry Beach.
# Retrieving Results for Index 6: Karratha.
# Retrieving Results for Index 7: Near Coral Bay.
# Retrieving Results for Index 8: Yallingup.
# Retrieving Results for Index 9: Waterford West.
# Retrieving Results for Index 10: Gleneg.
# Retrieving Results for Index 11: Melaleuca Beach, Cowaramup Bay, Gracetown, .
# Retrieving Results for Index 12: Lake Macquarie.
# Retrieving Results for Index 13: Port MacDonnell.
# Retrieving Results for Index 14: Blackwall Reach.
# Retrieving Results for Index 15: 13th Beach.
# Retrieving Results for Index 16: Cable Beach.
# Retrieving Results for Index 17: D’Estrees Bay near Kangaroo Island.
# Retrieving Results for Index 18: Cable Beach.
# Retrieving Results for Index 19: Town Beach, Port Macquarie.
# Retrieving Results for Index 20: Britomart Reef.
# Retrieving Results for Index 21: Kelp Beds Beach (Kelpies).
# Missing field/result... skipping.
# Retrieving Results for Index 22: Toms Surf break, Hamersley Pool, North Beach, Perth.
# Retrieving Results for Index 23: Fraser Island.
# Retrieving Results for Index 24: Cabarita Beach.
# Retrieving Results for Index 25: Greenmount Beach, Coolangatta.
# Retrieving Results for Index 26: Forster.
# Retrieving Results for Index 27: Shelly Beach, Port Macquarie.
# Retrieving Results for Index 28: Bunker Bay Beach.
# Retrieving Results for Index 29: Tenth Island.
# Retrieving Results for Index 30: Off Stanley.
# Retrieving Results for Index 31: Fitzroy Island.
# Retrieving Results for Index 32: Wilsons Headland.
# Retrieving Results for Index 33: Fraser Island.
# Retrieving Results for Index 34: Salt Beach near Kingscliff.
# Retrieving Results for Index 35: Tantabitti Beach, Nigaloo.
# Retrieving Results for Index 36: Lucinda.
# Retrieving Results for Index 37: Southside Beach, near Geelong.
# Retrieving Results for Index 38: Killick Creek near Crescent Head.
# Retrieving Results for Index 39: North West Island.
# Retrieving Results for Index 40: Wamberal Beach.
# Retrieving Results for Index 41: Cairns.
# Retrieving Results for Index 42: Windang Beach.
# Retrieving Results for Index 43: North West Island.
# Retrieving Results for Index 44: Cull Island / Esperance.
# Retrieving Results for Index 45: Esperance.
# Retrieving Results for Index 46: North West Island.
# Retrieving Results for Index 47: Shellharbour.
# Retrieving Results for Index 48: Exmouth.
# Retrieving Results for Index 49: Bargara.
# Retrieving Results for Index 50: Elliot Head, near Bundaberg..
# Retrieving Results for Index 51: Off Airlie Beach, Whitsundays.
# Retrieving Results for Index 52: Woorim Beach, Bribie Island,.
# Retrieving Results for Index 53: Lighthouse Beach.
# Retrieving Results for Index 54: Nightcliff Jetty, Darwin.
# Retrieving Results for Index 55: Burns Beach, Perth.
# Retrieving Results for Index 56: Magra Islet.
# Retrieving Results for Index 57: Pelican Waters, Caloundra.
# Retrieving Results for Index 58: Maatsuyker Island .
# Retrieving Results for Index 59: Lennox Head.
# Retrieving Results for Index 60: Yandaran Beach.
# Retrieving Results for Index 61: Tomaree.
# Retrieving Results for Index 62: Line Reef.
# Retrieving Results for Index 63: Belongil Bay.
# Retrieving Results for Index 64: Groote Eylandt.
# Retrieving Results for Index 65: Urunga area.
# Retrieving Results for Index 66: North Cottesloe .
# Retrieving Results for Index 67: Catseye Beach, Hamilton Island, Whitsundays.
# Retrieving Results for Index 68: nan.
# Retrieving Results for Index 69: Nambucca.
# Retrieving Results for Index 70: South Steyne.
# Retrieving Results for Index 71: Off Nhulunbuy.
# Retrieving Results for Index 72: 7 Mile Beach, Gerroa.
# Retrieving Results for Index 73: Moffat Beach.
# Retrieving Results for Index 74: Pyramids Beach, Mandurah.
# Retrieving Results for Index 75: Shelly Beach, Ballina.
# Retrieving Results for Index 76: Cid Harbor, Whitsundays.
# Retrieving Results for Index 77: Guillotines surf break, Shire of Augusta Margaret River.
# Retrieving Results for Index 78: Samurai Beach.
# Retrieving Results for Index 79: Two Rocks near Three Mile Reef.
# Retrieving Results for Index 80: Swain Reef.
# Retrieving Results for Index 81: Groote Eylandt.
# Retrieving Results for Index 82: Cid Harbor, Whitsundays.
# Retrieving Results for Index 83: Cid Harbor, Whitsundays.
# Retrieving Results for Index 84: Arrawarra Headland.
# Retrieving Results for Index 85: Flat Rock, Ballina.
# Retrieving Results for Index 86: Cairns Aquarium.
# Retrieving Results for Index 87: Dugong Bay.
# Retrieving Results for Index 88: Sharpes Beach, Ballina.
# Retrieving Results for Index 89: Gearys Beach.
# Retrieving Results for Index 90: Lennox Head.
# Retrieving Results for Index 91: Surfers Point, Prevelly.
# Retrieving Results for Index 92: South Point, Gracetown.
# Retrieving Results for Index 93: Lefthanders, Margaret River Area.
# Retrieving Results for Index 94: Cobblestones, Margaret River Area.
# Retrieving Results for Index 95: Waterman's Bay.
# Retrieving Results for Index 96: Lorne.
# Retrieving Results for Index 97: Winkipop.
# Retrieving Results for Index 98: Little Congwong Beach, La Perouse .
# Retrieving Results for Index 99: Westernport Bay.
# Retrieving Results for Index 100: Surf Beach, Kiama.
# Retrieving Results for Index 101: Mooloolaba Beach.
# Retrieving Results for Index 102: Avalon Point, Manurah.
# Retrieving Results for Index 103: Cone Bay.
# Retrieving Results for Index 104: Lizard Island.
# Retrieving Results for Index 105: Martin Islet.
# Retrieving Results for Index 106: South Point, Gracetown.
# Retrieving Results for Index 107: Avoca Beach.
# Retrieving Results for Index 108: Magnetic Island.
# Retrieving Results for Index 109: Birubi Point.
# Retrieving Results for Index 110: Normanville.
# Retrieving Results for Index 111: Gracetown.
# Retrieving Results for Index 112: Esperance.
# Retrieving Results for Index 113: Sam's Creek area.
# Retrieving Results for Index 114: Iluka Beach.
# Retrieving Results for Index 115: Cathedral Rock.
# Retrieving Results for Index 116: Floreat Beach.
# Retrieving Results for Index 117: Point Casuarina, Bunbury.
# Retrieving Results for Index 118: Flinders, Mornington Penisula.
# Retrieving Results for Index 119: Evans Head.
# Retrieving Results for Index 120: Weipa.
# Retrieving Results for Index 121: Kelpies near Wylie Bay.
# Retrieving Results for Index 122: Moreton Bay.
# Retrieving Results for Index 123: The Farm.
# Retrieving Results for Index 124: Mauds Point.
# Retrieving Results for Index 125: Falcon Bay Beach, Mandurah.
# Retrieving Results for Index 126: Eva Rock.
# Retrieving Results for Index 127: Boot Reef, Torres Strait.
# Retrieving Results for Index 128: Clairview.
# Retrieving Results for Index 129: nan.
# Missing field/result... skipping.
# Retrieving Results for Index 130: Merimbula.
# Retrieving Results for Index 131: Bundegi Sanctuary Zone, Ningaloo.
# Missing field/result... skipping.
# Retrieving Results for Index 132: Trigg Beach.
# Retrieving Results for Index 133: Merimbula.
# Retrieving Results for Index 134: Booti Booti National Park.
# Retrieving Results for Index 135: Queenscliff.
# Retrieving Results for Index 136: Broken Head Beach.
# Retrieving Results for Index 137: Kings Beach, Caloundra.
# Retrieving Results for Index 138: Sharpes Beach, Ballina.
# Retrieving Results for Index 139: Lighthouse Beach, Ballina.
# Retrieving Results for Index 140: Thirteenth Beach.
# Retrieving Results for Index 141: Bells Beach.
# Retrieving Results for Index 142: Bunbury.
# Retrieving Results for Index 143: Injidup .
# Retrieving Results for Index 144: Near Albany.
# Retrieving Results for Index 145: Sharpes Beach, Ballina.
# Retrieving Results for Index 146: Clifton Beach.
# Retrieving Results for Index 147: 20 k off The Spit, off the Gold Coast.
# Missing field/result... skipping.
# Retrieving Results for Index 148: Palm Cove .
# Retrieving Results for Index 149: Coral Bay.
# Retrieving Results for Index 150: Mindarie.
# Retrieving Results for Index 151: Kingscliff.
# Retrieving Results for Index 152: Falcon Beach, Mandurah.
# Retrieving Results for Index 153: First Sun Beach, Byron Bay.
# Retrieving Results for Index 154: Bombo Beach.
# Retrieving Results for Index 155: North Cronulla Beach.
# Retrieving Results for Index 156: Wrights Bay.
# Retrieving Results for Index 157: Nettley Bay.
# Retrieving Results for Index 158: Stradbroke Island.
# Retrieving Results for Index 159: Hams Beach.
# Retrieving Results for Index 160: Happy Valley Beach, Caloundra.
# Retrieving Results for Index 161: Heron Island.
# Retrieving Results for Index 162: Miall Island.

# %%
shark_df.head()
# Out:
#   Case Number         Date    Year        Type    Country               Area  \
# 0  2021.07.19  19-Jul-2021  2021.0  Unprovoked  AUSTRALIA  Western Australia
# 1  2021.07.05  05-Jul-2021  2021.0  Unprovoked  AUSTRALIA    New South Wales
# 2  2021.06.23  23-Jun-2021  2021.0  Unprovoked  AUSTRALIA  Western Australia
# 3  2021.06.11  11-Jun-2021  2021.0  Unprovoked  AUSTRALIA  Western Australia
# 4  2021.05.21  21-May-2021  2021.0  Unprovoked  AUSTRALIA  Western Australia
#
#             Location      Activity Sex   Age  ...   Time  \
# 0    Rottnest Island       Surfing    M  NaN  ...  12h30
# 1      Crescent Head       Surfing    M   25  ...  16h30
# 2       Gum Tree Bay       Surfing    M   25  ...  14h00
# 3  Five Fingers Reef    Snorkeling    M   10  ...  11h00
# 4     Quondong Beach  Spearfishing    M   48  ...  11h20
#
#                    Species                        pdf  \
# 0           White shark, 3m   2021.07.19-Rottnest.pdf
# 1                       NaN    2021.07.05-Hoffman.pdf
# 2                       NaN      2021.06.23-Dodds.pdf
# 3  Bronze whaler shark, 2 m   2021.06.11-Bartlett.pdf
# 4                       NaN  2021.05.21-Highlands.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2021.07.19
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2021.07.05
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2021.06.23
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2021.06.11
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2021.05.21
#
#   Case Number.2 original order      lat      lng
# 0    2021.07.19           6668 -32.0064  115.507
# 1    2021.07.05           6661  -31.177  152.911
# 2    2021.06.23           6655 -29.7844  114.962
# 3    2021.06.11           6649 -23.1797  113.766
# 4    2021.05.21           6646 -17.5804  122.157
#
# [5 rows x 22 columns]

# %%
# find record where location is not given
no_loc = shark_df.loc[shark_df['Location'].isna()]
print(no_loc)

# this record is not in WA, so will not affect study too much, so will be dropped from df
shark_df = shark_df.loc[shark_df['Location'].notna()]
# Out:
#       Case Number                  Date    Year      Type    Country  \
# 68   2018.12.15.b           15-Dec-2018  2018.0  Provoked  AUSTRALIA
# 129  2017.01.08.R  Reported 08-Jan-2017     NaN   Invalid  AUSTRALIA
#
#                 Area Location      Activity Sex  Age  ...   Time  \
# 68   New South Wales      NaN           NaN    M  48  ...  11h00
# 129       Queensland      NaN  Spearfishing    M  35  ...    NaN
#
#             Species                            pdf  \
# 68   Wobbegong shark      2018.12.15-Wobbegong.pdf
# 129       Bull shark  2017.01.08.R-KerryDaniel.pdf
#
#                                           href formula  \
# 68   http://sharkattackfile.net/spreadsheets/pdf_di...
# 129  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   href Case Number.1  \
# 68   http://sharkattackfile.net/spreadsheets/pdf_di...  2018.12.15.b
# 129  http://sharkattackfile.net/spreadsheets/pdf_di...  2017.01.08.R
#
#     Case Number.2 original order      lat      lng
# 68   2018.12.15.b           6391 -34.4663  150.848
# 129  2017.01.08.R           6134
#
# [2 rows x 22 columns]

# %%
# convert lat and lng results to numbers
shark_df['lat'] = pd.to_numeric(shark_df['lat'])
shark_df['lng'] = pd.to_numeric(shark_df['lng'])

# %%
empty = shark_df.isna()
empty.sum()
# Out:
# Case Number        0
# Date               0
# Year               0
# Type               0
# Country            0
# Area               0
# Location           0
# Activity           6
# Sex                5
# Age               45
# Injury             1
# Fatal (Y/N)        7
# Time              25
# Species           57
# pdf                0
# href formula       0
# href               0
# Case Number.1      0
# Case Number.2      0
# original order     0
# lat                3
# lng                3
# dtype: int64

# %%
# find rows with empty locations
shark_df_empty_loc = shark_df.loc[shark_df['lat'].isna()]
shark_df_empty_loc
# Out:
#     Case Number         Date    Year        Type    Country  \
# 21   2020.10.09  09-Oct-2020  2020.0  Unprovoked  AUSTRALIA
# 131  2016.12.24  24-Dec-2016  2016.0  Unprovoked  AUSTRALIA
# 147  2016.07.20  20-Jul-2016  2016.0    Provoked  AUSTRALIA
#
#                   Area                               Location    Activity  \
# 21   Western Australia              Kelp Beds Beach (Kelpies)     Surfing
# 131  Western Australia       Bundegi Sanctuary Zone, Ningaloo  Snorkeling
# 147         Queensland  20 k off The Spit, off the Gold Coast     Fishing
#
#     Sex   Age  ...        Time        Species                       pdf  \
# 21     M   52  ...       10h45        4m shark    2020.10.09-Sharpe.pdf
# 131    F  NaN  ...     Morning   a small shark  2016.12.24-Ningaloo.pdf
# 147    M   31  ...  After noon  reef shark, 1m     2016.07.20-Burck.pdf
#
#                                           href formula  \
# 21   http://sharkattackfile.net/spreadsheets/pdf_di...
# 131  http://sharkattackfile.net/spreadsheets/pdf_di...
# 147  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   href Case Number.1  \
# 21   http://sharkattackfile.net/spreadsheets/pdf_di...    2020.10.09
# 131  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.12.24
# 147  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.07.20
#
#     Case Number.2 original order lat  lng
# 21     2020.10.09           6586 NaN  NaN
# 131    2016.12.24           6130 NaN  NaN
# 147    2016.07.20           6079 NaN  NaN
#
# [3 rows x 22 columns]

# %%
# these rows are important to the findings, so will need to find location data for them

# Build URL using the Google Maps API

base_url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"

params = {"key": g_key, "inputtype": "textquery", "fields":"geometry"}

# Sam's Creek Area, Point Samson WA, case number 2017.09.10.b
params['input'] = "Point Samson WA"
response = requests.get(base_url, params=params)
results = response.json()
shark_df.loc[shark_df['Case Number'] == "2017.09.10.b",'lat'] = results['candidates'][0]['geometry']['location']['lat']
shark_df.loc[shark_df['Case Number'] == "2017.09.10.b",'lng'] = results['candidates'][0]['geometry']['location']['lng']

# bundegi sanctuary zone, case number 2016.12.24
params['input'] = "bundegi sanctuary zone"
response = requests.get(base_url, params=params)
results = response.json()
shark_df.loc[shark_df['Case Number'] == "2016.12.24",'lat'] = results['candidates'][0]['geometry']['location']['lat']
shark_df.loc[shark_df['Case Number'] == "2016.12.24",'lng'] = results['candidates'][0]['geometry']['location']['lng']

# The Spit Gold Coast, Seaworld Drive, Main Beach QLD, case number 2016.07.20
params['input'] = "The Spit Gold Coast, Seaworld Drive, Main Beach QLD"
response = requests.get(base_url, params=params)
results = response.json()
shark_df.loc[shark_df['Case Number'] == "2016.07.20",'lat'] = results['candidates'][0]['geometry']['location']['lat']
shark_df.loc[shark_df['Case Number'] == "2016.07.20",'lng'] = results['candidates'][0]['geometry']['location']['lng']

# Kelp Beds surf break, Wylie Bay, Esperance, case number 2020.10.09
params['input'] = "Wylie Bay, Esperance"
response = requests.get(base_url, params=params)
results = response.json()
shark_df.loc[shark_df['Case Number'] == "2020.10.09",'lat'] = results['candidates'][0]['geometry']['location']['lat']
shark_df.loc[shark_df['Case Number'] == "2020.10.09",'lng'] = results['candidates'][0]['geometry']['location']['lng']

# %%
# export data
shark_df.to_csv("shark_geo.csv")
