# %%
# Dependencies
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import requests
import json
import gmaps
from config import g_key
gmaps.configure(api_key=g_key)

# %%
# import filtered shark csv file
filename = "Resource/Shark Data WA 2016-2020 (filtered).xlsx"
shark_data = pd.read_excel(filename)
shark_data.head()
# Out:
#   Case Number         Date  Year          Type    Country               Area  \
# 0  2020.01.17  17-Jan-2020  2020    Unprovoked  AUSTRALIA    New South Wales
# 1  2020.01.07  07-Jan-2020  2020    Unprovoked  AUSTRALIA         Queensland
# 2  2020.01.05  05-Jan-2020  2020    Unprovoked  AUSTRALIA  Western Australia
# 3  2020.01.02  02-Jan-2020  2020  Questionable  AUSTRALIA  Western Australia
# 4  2019.12.30  30-Dec-2019  2019    Unprovoked  AUSTRALIA         Queensland
#
#                   Location                              Activity  \
# 0            Windang Beach                               Surfing
# 1        North West Island                              Swimming
# 2  Cull Island / Esperance                          Scuba diving
# 3                Esperance  Swimming after being swept off rocks
# 4        North West Island                              Swimming
#
#               Name  Age                             Injury Fatal (Y/N)   Time  \
# 0   Will Schroeter   59  Laceration ot left ankle and foot           N  08h00
# 1      Miah Holmes    7                 Lacerations to leg           N  17h30
# 2     Gary Johnson   57                              FATAL           Y  13h00
# 3  Eric Birighitti   21   Probable drowning and scavenging           Y  16h10
# 4             male  30s               Minor injury to hand           N  12h58
#
#                                           Species   \
# 0                                  "A small shark"
# 1                                      Lemon shark
# 2                                      White shark
# 3                                              NaN
# 4  Shovelnose "shark" which is a ray, not a shark)
#
#                               Investigator or Source
# 0  B. Myatt & M. Michaelson, GSAF; K. McMurray, T...
# 1  B. Myatt & M. Michaelson, GSAF; K. McMurray, T...
# 2                                     B. Myatt, GSAF
# 3  B. Myatt & M. Michaelson, GSAF; K. McMurray, T...
# 4                                     B. Myatt, GSAF

# %%
shark_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114 entries, 0 to 113
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             114 non-null    object
#  1   Date                    114 non-null    object
#  2   Year                    114 non-null    int64
#  3   Type                    114 non-null    object
#  4   Country                 114 non-null    object
#  5   Area                    114 non-null    object
#  6   Location                113 non-null    object
#  7   Activity                112 non-null    object
#  8   Name                    111 non-null    object
#  9   Age                     80 non-null     object
#  10  Injury                  114 non-null    object
#  11  Fatal (Y/N)             109 non-null    object
#  12  Time                    92 non-null     object
#  13  Species                 74 non-null     object
#  14  Investigator or Source  113 non-null    object
# dtypes: int64(1), object(14)
# memory usage: 13.5+ KB

# %%
shark_data['Area'].unique()
# Out:
# array(['New South Wales', 'Queensland', 'Western Australia',
#        'Northern Territory', 'Tasmania', 'Westerm Australia', 'Victoria',
#        'South Australia'], dtype=object)

# %%
# clean up misspelled State
shark_data['Area'] = shark_data['Area'].replace({'Westerm Australia':'Western Australia'})

# %%
# remove unwanted columns
shark_df = shark_data.drop(['Name','Investigator or Source'], axis = 1)

# %%
shark_df['Location'].nunique()
# Out:
# 106

# %%
# match location to lat and long coordinates

# create columns to hold data
shark_df['lat']=""
shark_df['lng']=""

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"

params = {"key": g_key, "inputtype": "textquery", "fields":"geometry"}

for index, row in shark_df.iterrows():
    # get extra parameters
    params['input'] = (f'{row["Location"]}, {row["Area"]}')
    
    # Run request
    print(f"Retrieving Results for Index {index}: {row['Location']}.")
    response = requests.get(base_url, params=params)
    results = response.json()

    # Extract lat/lng
    try:
        shark_df.loc[index, 'lat'] = results['candidates'][0]['geometry']['location']['lat']
        shark_df.loc[index, 'lng'] = results['candidates'][0]['geometry']['location']['lng'] 
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# Retrieving Results for Index 0: Windang Beach.
# Retrieving Results for Index 1: North West Island.
# Retrieving Results for Index 2: Cull Island / Esperance.
# Retrieving Results for Index 3: Esperance.
# Retrieving Results for Index 4: North West Island.
# Retrieving Results for Index 5: Shellharbour.
# Retrieving Results for Index 6: Exmouth.
# Retrieving Results for Index 7: Bargara.
# Retrieving Results for Index 8: Elliot Head, near Bundaberg..
# Retrieving Results for Index 9: Off Airlie Beach, Whitsundays.
# Retrieving Results for Index 10: Woorim Beach, Bribie Island,.
# Retrieving Results for Index 11: Lighthouse Beach.
# Retrieving Results for Index 12: Nightcliff Jetty, Darwin.
# Retrieving Results for Index 13: Burns Beach, Perth.
# Retrieving Results for Index 14: Magra Islet.
# Retrieving Results for Index 15: Pelican Waters, Caloundra.
# Retrieving Results for Index 16: Maatsuyker Island.
# Retrieving Results for Index 17: Lennox Head.
# Retrieving Results for Index 18: Yandaran Beach.
# Retrieving Results for Index 19: Tomaree.
# Retrieving Results for Index 20: Line Reef.
# Retrieving Results for Index 21: Belongil Bay.
# Retrieving Results for Index 22: Urunga area.
# Retrieving Results for Index 23: North Cottesloe.
# Retrieving Results for Index 24: Catseye Beach, Hamilton Island, Whitsundays.
# Retrieving Results for Index 25: nan.
# Retrieving Results for Index 26: Nambucca.
# Retrieving Results for Index 27: Off Nhulunbuy.
# Retrieving Results for Index 28: 7 Mile Beach, Gerroa.
# Retrieving Results for Index 29: Pyramids Beach, Mandurah.
# Retrieving Results for Index 30: Shelly Beach, Ballina.
# Retrieving Results for Index 31: Cid Harbor, Whitsundays.
# Retrieving Results for Index 32: Guillotines surf break, Shire of Augusta Margaret River.
# Retrieving Results for Index 33: Samurai Beach.
# Retrieving Results for Index 34: Two Rocks near Three Mile Reef.
# Retrieving Results for Index 35: Swain Reef.
# Retrieving Results for Index 36: Arrawarra Headland.
# Retrieving Results for Index 37: Flat Rock, Ballina.
# Retrieving Results for Index 38: Cairns Aquarium.
# Retrieving Results for Index 39: Dugong Bay.
# Retrieving Results for Index 40: Sharpes Beach, Ballina.
# Retrieving Results for Index 41: Gearys Beach.
# Retrieving Results for Index 42: Lennox Head.
# Retrieving Results for Index 43: Surfers Point, Prevelly.
# Retrieving Results for Index 44: South Point, Gracetown.
# Retrieving Results for Index 45: Lefthanders, Margaret River Area.
# Retrieving Results for Index 46: Cobblestones, Margaret River Area.
# Retrieving Results for Index 47: Waterman's Bay.
# Retrieving Results for Index 48: Lorne.
# Retrieving Results for Index 49: Winkipop.
# Retrieving Results for Index 50: Little Congwong Beach, La Perouse.
# Retrieving Results for Index 51: Westernport Bay.
# Retrieving Results for Index 52: Surf Beach, Kiama.
# Retrieving Results for Index 53: Mooloolaba Beach.
# Retrieving Results for Index 54: Avalon Point, Manurah.
# Retrieving Results for Index 55: Cone Bay.
# Retrieving Results for Index 56: Lizard Island.
# Retrieving Results for Index 57: Martin Islet.
# Retrieving Results for Index 58: South Point, Gracetown.
# Retrieving Results for Index 59: Avoca Beach.
# Retrieving Results for Index 60: Magnetic Island.
# Retrieving Results for Index 61: Birubi Point.
# Retrieving Results for Index 62: Normanville.
# Retrieving Results for Index 63: Gracetown.
# Retrieving Results for Index 64: Esperance.
# Retrieving Results for Index 65: Sam's Creek area.
# Retrieving Results for Index 66: Iluka Beach.
# Retrieving Results for Index 67: Cathedral Rock.
# Retrieving Results for Index 68: Floreat Beach.
# Retrieving Results for Index 69: Point Casuarina, Bunbury.
# Retrieving Results for Index 70: Flinders, Mornington Penisula.
# Retrieving Results for Index 71: Evans Head.
# Retrieving Results for Index 72: Weipa.
# Retrieving Results for Index 73: Kelpies near Wylie Bay.
# Retrieving Results for Index 74: Moreton Bay.
# Retrieving Results for Index 75: The Farm.
# Retrieving Results for Index 76: Mauds Point.
# Retrieving Results for Index 77: Falcon Bay Beach, Mandurah.
# Retrieving Results for Index 78: Eva Rock.
# Retrieving Results for Index 79: Boot Reef, Torres Strait.
# Retrieving Results for Index 80: Clairview.
# Retrieving Results for Index 81: Merimbula.
# Retrieving Results for Index 82: Bundegi Sanctuary Zone, Ningaloo.
# Missing field/result... skipping.
# Retrieving Results for Index 83: Trigg Beach.
# Retrieving Results for Index 84: Merimbula.
# Retrieving Results for Index 85: Booti Booti National Park.
# Retrieving Results for Index 86: Queenscliff.
# Retrieving Results for Index 87: Broken Head Beach.
# Retrieving Results for Index 88: Kings Beach, Caloundra.
# Retrieving Results for Index 89: Sharpes Beach, Ballina.
# Retrieving Results for Index 90: Lighthouse Beach, Ballina.
# Retrieving Results for Index 91: Thirteenth Beach.
# Retrieving Results for Index 92: Bells Beach.
# Retrieving Results for Index 93: Bunbury.
# Retrieving Results for Index 94: Injidup.
# Retrieving Results for Index 95: Near Albany.
# Retrieving Results for Index 96: Sharpes Beach, Ballina.
# Retrieving Results for Index 97: Clifton Beach.
# Retrieving Results for Index 98: 20 k off The Spit, off the Gold Coast.
# Missing field/result... skipping.
# Retrieving Results for Index 99: Palm Cove.
# Retrieving Results for Index 100: Coral Bay.
# Retrieving Results for Index 101: Mindarie.
# Retrieving Results for Index 102: Kingscliff.
# Retrieving Results for Index 103: Falcon Beach, Mandurah.
# Retrieving Results for Index 104: First Sun Beach, Byron Bay.
# Retrieving Results for Index 105: Bombo Beach.
# Retrieving Results for Index 106: North Cronulla Beach.
# Retrieving Results for Index 107: Wrights Bay.
# Retrieving Results for Index 108: Nettley Bay.
# Retrieving Results for Index 109: Stradbroke Island.
# Retrieving Results for Index 110: Hams Beach.
# Retrieving Results for Index 111: Happy Valley Beach, Caloundra.
# Retrieving Results for Index 112: Heron Island.
# Retrieving Results for Index 113: Miall Island.

# %%
shark_df.head()
# Out:
#   Case Number         Date  Year          Type    Country               Area  \
# 0  2020.01.17  17-Jan-2020  2020    Unprovoked  AUSTRALIA    New South Wales
# 1  2020.01.07  07-Jan-2020  2020    Unprovoked  AUSTRALIA         Queensland
# 2  2020.01.05  05-Jan-2020  2020    Unprovoked  AUSTRALIA  Western Australia
# 3  2020.01.02  02-Jan-2020  2020  Questionable  AUSTRALIA  Western Australia
# 4  2019.12.30  30-Dec-2019  2019    Unprovoked  AUSTRALIA         Queensland
#
#                   Location                              Activity  Age  \
# 0            Windang Beach                               Surfing   59
# 1        North West Island                              Swimming    7
# 2  Cull Island / Esperance                          Scuba diving   57
# 3                Esperance  Swimming after being swept off rocks   21
# 4        North West Island                              Swimming  30s
#
#                               Injury Fatal (Y/N)   Time  \
# 0  Laceration ot left ankle and foot           N  08h00
# 1                 Lacerations to leg           N  17h30
# 2                              FATAL           Y  13h00
# 3   Probable drowning and scavenging           Y  16h10
# 4               Minor injury to hand           N  12h58
#
#                                           Species       lat      lng
# 0                                  "A small shark" -34.5343  150.875
# 1                                      Lemon shark -23.2951  151.708
# 2                                      White shark -33.9222  121.903
# 3                                              NaN -33.8613  121.891
# 4  Shovelnose "shark" which is a ray, not a shark) -23.2951  151.708

# %%
# find record where location is not given
no_loc = shark_df.loc[shark_df['Location'].isna()]
print(no_loc)

# this record is not in WA, so will not affect study too much, so will be dropped from df
shark_df = shark_df.loc[shark_df['Location'].notna()]
# Out:
#      Case Number         Date  Year      Type    Country             Area  \
# 25  2018.12.15.b  15-Dec-2018  2018  Provoked  AUSTRALIA  New South Wales
#
#    Location Activity Age             Injury Fatal (Y/N)   Time  \
# 25      NaN      NaN  48  PROVOKED INCIDENT           N  11h00
#
#            Species       lat      lng
# 25  Wobbegong shark -34.4663  150.848

# %%
# convert lat and lng results to numbers
shark_df['lat'] = pd.to_numeric(shark_df['lat'])
shark_df['lng'] = pd.to_numeric(shark_df['lng'])

# %%
empty = shark_df.isna()
empty.sum()
# Out:
# Case Number     0
# Date            0
# Year            0
# Type            0
# Country         0
# Area            0
# Location        0
# Activity        1
# Age            34
# Injury          0
# Fatal (Y/N)     5
# Time           22
# Species        40
# lat             2
# lng             2
# dtype: int64

# %%
# find rows with empty locations
shark_df_empty_loc = shark_df.loc[shark_df['lat'].isna()]
shark_df_empty_loc
# Out:
#    Case Number         Date  Year        Type    Country               Area  \
# 82  2016.12.24  24-Dec-2016  2016  Unprovoked  AUSTRALIA  Western Australia
# 98  2016.07.20  20-Jul-2016  2016    Provoked  AUSTRALIA         Queensland
#
#                                  Location    Activity  Age  \
# 82       Bundegi Sanctuary Zone, Ningaloo  Snorkeling  NaN
# 98  20 k off The Spit, off the Gold Coast     Fishing   31
#
#                                                Injury Fatal (Y/N)        Time  \
# 82                                     Buttock bitten           N     Morning
# 98  Laceration to left calf from hooked shark PROV...           N  After noon
#
#           Species   lat  lng
# 82   a small shark  NaN  NaN
# 98  reef shark, 1m  NaN  NaN

# %%
# these rows are important to the findings, so will need to find location data for them

# Build URL using the Google Maps API

base_url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"

params = {"key": g_key, "inputtype": "textquery", "fields":"geometry"}

# Sam's Creek Area, Point Samson WA, case number 2017.09.10.b
params['input'] = "Point Samson WA"
response = requests.get(base_url, params=params)
results = response.json()
shark_df.loc[shark_df['Case Number'] == "2017.09.10.b",'lat'] = results['candidates'][0]['geometry']['location']['lat']
shark_df.loc[shark_df['Case Number'] == "2017.09.10.b",'lng'] = results['candidates'][0]['geometry']['location']['lng']

# bundegi sanctuary zone, case number 2016.12.24
params['input'] = "bundegi sanctuary zone"
response = requests.get(base_url, params=params)
results = response.json()
shark_df.loc[shark_df['Case Number'] == "2016.12.24",'lat'] = results['candidates'][0]['geometry']['location']['lat']
shark_df.loc[shark_df['Case Number'] == "2016.12.24",'lng'] = results['candidates'][0]['geometry']['location']['lng']

# The Spit Gold Coast, Seaworld Drive, Main Beach QLD, case number 2016.07.20
params['input'] = "The Spit Gold Coast, Seaworld Drive, Main Beach QLD"
response = requests.get(base_url, params=params)
results = response.json()
shark_df.loc[shark_df['Case Number'] == "2016.07.20",'lat'] = results['candidates'][0]['geometry']['location']['lat']
shark_df.loc[shark_df['Case Number'] == "2016.07.20",'lng'] = results['candidates'][0]['geometry']['location']['lng']

# %%
# Create a map with markers
marker_locations = shark_df[['lat', 'lng']]

# Create a marker_layer 
fig = gmaps.figure()
markers = gmaps.marker_layer(marker_locations)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
