# %%
# Dependencies
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import requests
import json
import gmaps
from config import g_key
gmaps.configure(api_key=g_key)

# %%
# import filtered shark csv file
filename = "Resource/Shark Data WA 2016-2021 (filtered).xls"
shark_data = pd.read_excel(filename)
shark_data.head()
# Out:
#     Case Number         Date    Year        Type    Country             Area  \
# 0    2016.12.06  06-Dec-2016  2016.0    Provoked  AUSTRALIA  New South Wales
# 1    2020.11.02  02-Nov-2020  2020.0  Unprovoked  AUSTRALIA  New South Wales
# 2  2017.09.10.a  10-Sep-2017  2017.0  Unprovoked  AUSTRALIA  New South Wales
# 3  2019.02.04.a  04-Feb-2019  2019.0  Unprovoked  AUSTRALIA  New South Wales
# 4    2019.02.17  17-Feb-2019  2019.0  Unprovoked  AUSTRALIA  New South Wales
#
#                      Location      Activity            Name Sex   ...  \
# 0                   Merimbula  Surf fishing  Jesse Phillips    M  ...
# 1  Town Beach, Port Macquarie       Surfing            male    M  ...
# 2                 Iluka Beach       Surfing     Abe McGrath    M  ...
# 3                 Urunga area       Surfing  Matt Gallagher    M  ...
# 4                Belongil Bay       Surfing    Sam Edwardes    M  ...
#
#   Fatal (Y/N)   Time                 Species   \
# 0           N  Night      Wobbegong shark, 2m
# 1           N   Dawn                      NaN
# 2           N   Dawn  White shark, 3 to 3.5m
# 3           N   Dawn                      NaN
# 4           N   Dawn                      NaN
#
#             Investigator or Source                           pdf  \
# 0                 Bay 93.9 Geelong       2016.12.06-Phillips.pdf
# 1                   B. Myatt, GSAF  2020.11.02-PortMacquarie.pdf
# 2                   B. Myatt, GSAF      2017.09.10.a-McGrath.pdf
# 3  K. McMurray, TrackingSharks.com    2019.02.04.a-Gallagher.pdf
# 4                   B. Myatt, GSAF       2019.02.17-Edwardes.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.12.06
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2020.11.02
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...  2017.09.10.a
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...  2019.02.04.a
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2019.02.17
#
#   Case Number.2 original order
# 0    2016.12.06           6125
# 1    2020.11.02           6593
# 2  2017.09.10.a           6234
# 3  2019.02.04.a           6400
# 4    2019.02.17           6404
#
# [5 rows x 22 columns]

# %%
shark_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163 entries, 0 to 162
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             163 non-null    object
#  1   Date                    163 non-null    object
#  2   Year                    162 non-null    float64
#  3   Type                    163 non-null    object
#  4   Country                 163 non-null    object
#  5   Area                    163 non-null    object
#  6   Location                161 non-null    object
#  7   Activity                156 non-null    object
#  8   Name                    160 non-null    object
#  9   Sex                     158 non-null    object
#  10  Age                     118 non-null    object
#  11  Injury                  162 non-null    object
#  12  Fatal (Y/N)             155 non-null    object
#  13  Time                    163 non-null    object
#  14  Species                 106 non-null    object
#  15  Investigator or Source  162 non-null    object
#  16  pdf                     163 non-null    object
#  17  href formula            163 non-null    object
#  18  href                    163 non-null    object
#  19  Case Number.1           163 non-null    object
#  20  Case Number.2           163 non-null    object
#  21  original order          163 non-null    int64
# dtypes: float64(1), int64(1), object(20)
# memory usage: 28.1+ KB

# %%
shark_data['Area'].unique()
# Out:
# array(['New South Wales', 'Queensland', 'Western Australia',
#        'New South Wales ', 'Victoria', 'Tasmania', 'South Australia',
#        'Westerm Australia', 'Northern Territory '], dtype=object)

# %%
# clean up misspelled State
shark_data['Area'] = shark_data['Area'].replace({'Westerm Australia':'Western Australia'})
shark_data['Area'] = shark_data['Area'].replace({'New South Wales ':'New South Wales'})

# %%
# remove unwanted columns
shark_df = shark_data.drop(['Name','Investigator or Source'], axis = 1)

# %%
shark_df['Location'].nunique()
# Out:
# 148

# %%
# match location to lat and long coordinates, using Google Maps API

# create columns to hold data
shark_df['lat']=""
shark_df['lng']=""

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"

params = {"key": g_key, "inputtype": "textquery", "fields":"geometry"}

for index, row in shark_df.iterrows():
    # get extra parameters
    params['input'] = (f'{row["Location"]}, {row["Area"]}')
    
    # Run request
    print(f"Retrieving Results for Index {index}: {row['Location']}.")
    response = requests.get(base_url, params=params)
    results = response.json()

    # Extract lat/lng
    try:
        shark_df.loc[index, 'lat'] = results['candidates'][0]['geometry']['location']['lat']
        shark_df.loc[index, 'lng'] = results['candidates'][0]['geometry']['location']['lng'] 
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# Retrieving Results for Index 0: Merimbula.
# Retrieving Results for Index 1: Town Beach, Port Macquarie.
# Retrieving Results for Index 2: Iluka Beach.
# Retrieving Results for Index 3: Urunga area.
# Retrieving Results for Index 4: Belongil Bay.
# Retrieving Results for Index 5: Shelly Beach, Ballina.
# Retrieving Results for Index 6: Moffat Beach.
# Retrieving Results for Index 7: Cable Beach.
# Retrieving Results for Index 8: Samurai Beach.
# Retrieving Results for Index 9: Lennox Head.
# Retrieving Results for Index 10: Nambucca.
# Retrieving Results for Index 11: Winkipop.
# Retrieving Results for Index 12: Broken Head Beach.
# Retrieving Results for Index 13: Blackwall Reach.
# Retrieving Results for Index 14: Killick Creek near Crescent Head.
# Retrieving Results for Index 15: Windang Beach.
# Retrieving Results for Index 16: Pelican Waters, Caloundra.
# Retrieving Results for Index 17: Cobblestones, Margaret River Area.
# Retrieving Results for Index 18: Cone Bay.
# Retrieving Results for Index 19: Point Casuarina, Bunbury.
# Retrieving Results for Index 20: Cable Beach.
# Retrieving Results for Index 21: Pyramids Beach, Mandurah.
# Retrieving Results for Index 22: Exmouth.
# Retrieving Results for Index 23: Burns Beach, Perth.
# Retrieving Results for Index 24: Guillotines surf break, Shire of Augusta Margaret River.
# Retrieving Results for Index 25: Birubi Point.
# Retrieving Results for Index 26: Booti Booti National Park.
# Retrieving Results for Index 27: Tenth Island.
# Retrieving Results for Index 28: Shelly Beach, Port Macquarie.
# Retrieving Results for Index 29: Catseye Beach, Hamilton Island, Whitsundays.
# Retrieving Results for Index 30: Surfers Point, Prevelly.
# Retrieving Results for Index 31: Trigg Beach.
# Retrieving Results for Index 32: Wamberal Beach.
# Retrieving Results for Index 33: Off Airlie Beach, Whitsundays.
# Retrieving Results for Index 34: Eva Rock.
# Retrieving Results for Index 35: Melaleuca Beach, Cowaramup Bay, Gracetown, .
# Retrieving Results for Index 36: Sharpes Beach, Ballina.
# Retrieving Results for Index 37: Cathedral Rock.
# Retrieving Results for Index 38: Sharpes Beach, Ballina.
# Retrieving Results for Index 39: Salt Beach near Kingscliff.
# Retrieving Results for Index 40: Kelp Beds Beach (Kelpies).
# Missing field/result... skipping.
# Retrieving Results for Index 41: Toms Surf break, Hamersley Pool, North Beach, Perth.
# Retrieving Results for Index 42: Five Fingers Reef.
# Retrieving Results for Index 43: nan.
# Retrieving Results for Index 44: Queenscliff.
# Retrieving Results for Index 45: North Cronulla Beach.
# Retrieving Results for Index 46: Turncurry Beach.
# Retrieving Results for Index 47: Quondong Beach.
# Retrieving Results for Index 48: North Cottesloe .
# Retrieving Results for Index 49: Mindarie.
# Retrieving Results for Index 50: Miall Island.
# Retrieving Results for Index 51: Fitzroy Island.
# Retrieving Results for Index 52: Floreat Beach.
# Retrieving Results for Index 53: Near Coral Bay.
# Retrieving Results for Index 54: Britomart Reef.
# Retrieving Results for Index 55: Two Rocks near Three Mile Reef.
# Retrieving Results for Index 56: Boot Reef, Torres Strait.
# Retrieving Results for Index 57: Sharpes Beach, Ballina.
# Retrieving Results for Index 58: First Sun Beach, Byron Bay.
# Retrieving Results for Index 59: Rottnest Island.
# Retrieving Results for Index 60: Line Reef.
# Retrieving Results for Index 61: Nettley Bay.
# Retrieving Results for Index 62: North West Island.
# Retrieving Results for Index 63: Cull Island / Esperance.
# Retrieving Results for Index 64: Lennox Head.
# Retrieving Results for Index 65: 7 Mile Beach, Gerroa.
# Retrieving Results for Index 66: Stradbroke Island.
# Retrieving Results for Index 67: Off Stanley.
# Retrieving Results for Index 68: Clairview.
# Retrieving Results for Index 69: Cid Harbor, Whitsundays.
# Retrieving Results for Index 70: Gum Tree Bay.
# Retrieving Results for Index 71: Fraser Island.
# Retrieving Results for Index 72: Tomaree.
# Retrieving Results for Index 73: Bunker Bay Beach.
# Retrieving Results for Index 74: D’Estrees Bay near Kangaroo Island.
# Retrieving Results for Index 75: Wilsons Headland.
# Retrieving Results for Index 76: Yallingup.
# Retrieving Results for Index 77: Sam's Creek area.
# Retrieving Results for Index 78: Lizard Island.
# Retrieving Results for Index 79: Lorne.
# Retrieving Results for Index 80: Karratha.
# Retrieving Results for Index 81: Flinders, Mornington Penisula.
# Retrieving Results for Index 82: Fraser Island.
# Retrieving Results for Index 83: Southside Beach, near Geelong.
# Retrieving Results for Index 84: Lighthouse Beach.
# Retrieving Results for Index 85: Surf Beach, Kiama.
# Retrieving Results for Index 86: Avoca Beach.
# Retrieving Results for Index 87: Kelpies near Wylie Bay.
# Retrieving Results for Index 88: Falcon Beach, Mandurah.
# Retrieving Results for Index 89: Esperance.
# Retrieving Results for Index 90: Yandaran Beach.
# Retrieving Results for Index 91: Crescent Head.
# Retrieving Results for Index 92: Gearys Beach.
# Retrieving Results for Index 93: Port MacDonnell.
# Retrieving Results for Index 94: Greenmount Beach, Coolangatta.
# Retrieving Results for Index 95: Cid Harbor, Whitsundays.
# Retrieving Results for Index 96: Waterford West.
# Retrieving Results for Index 97: North West Island.
# Retrieving Results for Index 98: North West Island.
# Retrieving Results for Index 99: Woorim Beach, Bribie Island,.
# Retrieving Results for Index 100: Cid Harbor, Whitsundays.
# Retrieving Results for Index 101: Waterman's Bay.
# Retrieving Results for Index 102: 13th Beach.
# Retrieving Results for Index 103: Bargara.
# Retrieving Results for Index 104: Mooloolaba Beach.
# Retrieving Results for Index 105: Gracetown.
# Retrieving Results for Index 106: Merimbula.
# Retrieving Results for Index 107: Kings Beach, Caloundra.
# Retrieving Results for Index 108: Lake Macquarie.
# Retrieving Results for Index 109: Magra Islet.
# Retrieving Results for Index 110: South Steyne.
# Retrieving Results for Index 111: The Farm.
# Retrieving Results for Index 112: Gleneg.
# Retrieving Results for Index 113: Bombo Beach.
# Retrieving Results for Index 114: Little Congwong Beach, La Perouse .
# Retrieving Results for Index 115: Palm Cove .
# Retrieving Results for Index 116: Lighthouse Beach, Ballina.
# Retrieving Results for Index 117: 20 k off The Spit, off the Gold Coast.
# Missing field/result... skipping.
# Retrieving Results for Index 118: Cabarita Beach.
# Retrieving Results for Index 119: Forster.
# Retrieving Results for Index 120: Nightcliff Jetty, Darwin.
# Retrieving Results for Index 121: Swain Reef.
# Retrieving Results for Index 122: Groote Eylandt.
# Retrieving Results for Index 123: South Point, Gracetown.
# Retrieving Results for Index 124: Normanville.
# Retrieving Results for Index 125: Moreton Bay.
# Retrieving Results for Index 126: Heron Island.
# Retrieving Results for Index 127: Off Nhulunbuy.
# Retrieving Results for Index 128: Injidup .
# Retrieving Results for Index 129: Hams Beach.
# Retrieving Results for Index 130: Cairns.
# Retrieving Results for Index 131: Wrights Bay.
# Retrieving Results for Index 132: Cairns Aquarium.
# Retrieving Results for Index 133: Mauds Point.
# Retrieving Results for Index 134: Falcon Bay Beach, Mandurah.
# Retrieving Results for Index 135: Bundegi Sanctuary Zone, Ningaloo.
# Retrieving Results for Index 136: Westernport Bay.
# Retrieving Results for Index 137: Tantabitti Beach, Nigaloo.
# Retrieving Results for Index 138: Lucinda.
# Retrieving Results for Index 139: Shellharbour.
# Retrieving Results for Index 140: Elliot Head, near Bundaberg..
# Retrieving Results for Index 141: Maatsuyker Island .
# Retrieving Results for Index 142: Groote Eylandt.
# Retrieving Results for Index 143: Arrawarra Headland.
# Retrieving Results for Index 144: Flat Rock, Ballina.
# Retrieving Results for Index 145: Dugong Bay.
# Retrieving Results for Index 146: Lefthanders, Margaret River Area.
# Retrieving Results for Index 147: Avalon Point, Manurah.
# Retrieving Results for Index 148: Martin Islet.
# Retrieving Results for Index 149: South Point, Gracetown.
# Retrieving Results for Index 150: Magnetic Island.
# Retrieving Results for Index 151: Esperance.
# Retrieving Results for Index 152: Evans Head.
# Retrieving Results for Index 153: Weipa.
# Retrieving Results for Index 154: nan.
# Missing field/result... skipping.
# Retrieving Results for Index 155: Thirteenth Beach.
# Retrieving Results for Index 156: Bells Beach.
# Retrieving Results for Index 157: Bunbury.
# Retrieving Results for Index 158: Near Albany.
# Retrieving Results for Index 159: Clifton Beach.
# Retrieving Results for Index 160: Coral Bay.
# Retrieving Results for Index 161: Kingscliff.
# Retrieving Results for Index 162: Happy Valley Beach, Caloundra.

# %%
shark_df.head()
# Out:
#     Case Number         Date    Year        Type    Country             Area  \
# 0    2016.12.06  06-Dec-2016  2016.0    Provoked  AUSTRALIA  New South Wales
# 1    2020.11.02  02-Nov-2020  2020.0  Unprovoked  AUSTRALIA  New South Wales
# 2  2017.09.10.a  10-Sep-2017  2017.0  Unprovoked  AUSTRALIA  New South Wales
# 3  2019.02.04.a  04-Feb-2019  2019.0  Unprovoked  AUSTRALIA  New South Wales
# 4    2019.02.17  17-Feb-2019  2019.0  Unprovoked  AUSTRALIA  New South Wales
#
#                      Location      Activity Sex  Age  ...   Time  \
# 0                   Merimbula  Surf fishing    M  20  ...  Night
# 1  Town Beach, Port Macquarie       Surfing    M  13  ...   Dawn
# 2                 Iluka Beach       Surfing    M  35  ...   Dawn
# 3                 Urunga area       Surfing    M  50  ...   Dawn
# 4                Belongil Bay       Surfing    M  41  ...   Dawn
#
#                   Species                            pdf  \
# 0      Wobbegong shark, 2m       2016.12.06-Phillips.pdf
# 1                      NaN  2020.11.02-PortMacquarie.pdf
# 2  White shark, 3 to 3.5m       2017.09.10.a-McGrath.pdf
# 3                      NaN    2019.02.04.a-Gallagher.pdf
# 4                      NaN       2019.02.17-Edwardes.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.12.06
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2020.11.02
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...  2017.09.10.a
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...  2019.02.04.a
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2019.02.17
#
#   Case Number.2 original order      lat      lng
# 0    2016.12.06           6125 -36.8875  149.906
# 1    2020.11.02           6593 -31.4295  152.919
# 2  2017.09.10.a           6234  -29.412  153.365
# 3  2019.02.04.a           6400    -30.5  153.017
# 4    2019.02.17           6404 -28.6337    153.6
#
# [5 rows x 22 columns]

# %%
# find record where location is not given
no_loc = shark_df.loc[shark_df['Location'].isna()]
print(no_loc)

# this record is not in WA, so will not affect study too much, so will be dropped from df
shark_df = shark_df.loc[shark_df['Location'].notna()]
# Out:
#       Case Number                  Date    Year      Type    Country  \
# 43   2018.12.15.b           15-Dec-2018  2018.0  Provoked  AUSTRALIA
# 154  2017.01.08.R  Reported 08-Jan-2017     NaN   Invalid  AUSTRALIA
#
#                 Area Location      Activity Sex  Age  ...     Time  \
# 43   New South Wales      NaN           NaN    M  48  ...      Day
# 154       Queensland      NaN  Spearfishing    M  35  ...  Unknown
#
#             Species                            pdf  \
# 43   Wobbegong shark      2018.12.15-Wobbegong.pdf
# 154       Bull shark  2017.01.08.R-KerryDaniel.pdf
#
#                                           href formula  \
# 43   http://sharkattackfile.net/spreadsheets/pdf_di...
# 154  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   href Case Number.1  \
# 43   http://sharkattackfile.net/spreadsheets/pdf_di...  2018.12.15.b
# 154  http://sharkattackfile.net/spreadsheets/pdf_di...  2017.01.08.R
#
#     Case Number.2 original order      lat      lng
# 43   2018.12.15.b           6391 -34.4663  150.848
# 154  2017.01.08.R           6134
#
# [2 rows x 22 columns]

# %%
# convert lat and lng results to numbers
shark_df['lat'] = pd.to_numeric(shark_df['lat'])
shark_df['lng'] = pd.to_numeric(shark_df['lng'])

# %%
empty = shark_df.isna()
empty.sum()
# Out:
# Case Number        0
# Date               0
# Year               0
# Type               0
# Country            0
# Area               0
# Location           0
# Activity           6
# Sex                5
# Age               45
# Injury             1
# Fatal (Y/N)        7
# Time               0
# Species           57
# pdf                0
# href formula       0
# href               0
# Case Number.1      0
# Case Number.2      0
# original order     0
# lat                2
# lng                2
# dtype: int64

# %%
# find rows with empty locations
shark_df_empty_loc = shark_df.loc[shark_df['lat'].isna()]
shark_df_empty_loc
# Out:
#     Case Number         Date    Year        Type    Country  \
# 40   2020.10.09  09-Oct-2020  2020.0  Unprovoked  AUSTRALIA
# 117  2016.07.20  20-Jul-2016  2016.0    Provoked  AUSTRALIA
#
#                   Area                               Location Activity Sex   \
# 40   Western Australia              Kelp Beds Beach (Kelpies)  Surfing    M
# 117         Queensland  20 k off The Spit, off the Gold Coast  Fishing    M
#
#     Age  ...  Time        Species                     pdf  \
# 40   52  ...   Day        4m shark  2020.10.09-Sharpe.pdf
# 117  31  ...  Dusk  reef shark, 1m   2016.07.20-Burck.pdf
#
#                                           href formula  \
# 40   http://sharkattackfile.net/spreadsheets/pdf_di...
# 117  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   href Case Number.1  \
# 40   http://sharkattackfile.net/spreadsheets/pdf_di...    2020.10.09
# 117  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.07.20
#
#     Case Number.2 original order lat  lng
# 40     2020.10.09           6586 NaN  NaN
# 117    2016.07.20           6079 NaN  NaN
#
# [2 rows x 22 columns]

# %%
# these rows are important to the findings, so will need to find location data for them

# Build URL using the Google Maps API

base_url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"

params = {"key": g_key, "inputtype": "textquery", "fields":"geometry"}

# Sam's Creek Area, Point Samson WA, case number 2017.09.10.b
params['input'] = "Point Samson WA"
response = requests.get(base_url, params=params)
results = response.json()
shark_df.loc[shark_df['Case Number'] == "2017.09.10.b",'lat'] = results['candidates'][0]['geometry']['location']['lat']
shark_df.loc[shark_df['Case Number'] == "2017.09.10.b",'lng'] = results['candidates'][0]['geometry']['location']['lng']

# bundegi sanctuary zone, case number 2016.12.24
params['input'] = "bundegi sanctuary zone"
response = requests.get(base_url, params=params)
results = response.json()
shark_df.loc[shark_df['Case Number'] == "2016.12.24",'lat'] = results['candidates'][0]['geometry']['location']['lat']
shark_df.loc[shark_df['Case Number'] == "2016.12.24",'lng'] = results['candidates'][0]['geometry']['location']['lng']

# The Spit Gold Coast, Seaworld Drive, Main Beach QLD, case number 2016.07.20
params['input'] = "The Spit Gold Coast, Seaworld Drive, Main Beach QLD"
response = requests.get(base_url, params=params)
results = response.json()
shark_df.loc[shark_df['Case Number'] == "2016.07.20",'lat'] = results['candidates'][0]['geometry']['location']['lat']
shark_df.loc[shark_df['Case Number'] == "2016.07.20",'lng'] = results['candidates'][0]['geometry']['location']['lng']

# Kelp Beds surf break, Wylie Bay, Esperance, case number 2020.10.09
params['input'] = "Wylie Bay, Esperance"
response = requests.get(base_url, params=params)
results = response.json()
shark_df.loc[shark_df['Case Number'] == "2020.10.09",'lat'] = results['candidates'][0]['geometry']['location']['lat']
shark_df.loc[shark_df['Case Number'] == "2020.10.09",'lng'] = results['candidates'][0]['geometry']['location']['lng']

# %%
# export data
shark_df.to_csv("Resource/shark_geo.csv")
